# %% [markdown]
# # Pytorch + HuggingFace를 활용한 NSMC (네이버 영화평 감정분류) 모델
# ## KoElectra Model
# 박장원님의 KoElectra-base_v3 모델 사용<br>
# https://github.com/monologg/KoELECTRA
#
# ## Dataset
# 네이버 영화 리뷰 데이터셋<br>
# https://github.com/e9t/nsmc
#
# ## References
# - https://huggingface.co/transformers/training.html
# - https://tutorials.pytorch.kr/beginner/data_loading_tutorial.html
# - https://tutorials.pytorch.kr/beginner/blitz/cifar10_tutorial.html
# - https://wikidocs.net/44249
#
# ## 주의사항
# 꼭 GPU로 해주세요 - 1epoch 당 약 20분 소요

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#  transformers 설치 ( 그 외 도구는 설치되었다고 가정 )
# HuggingFace transformers 설치 및 NSMC 데이터셋 다운로드
# !pip install transformers
# !wget https://raw.githubusercontent.com/e9t/nsmc/master/ratings_test.txt
# !wget https://raw.githubusercontent.com/e9t/nsmc/master/ratings_train.txt
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.6/dist-packages (4.1.1)
# Requirement already satisfied: sacremoses in /usr/local/lib/python3.6/dist-packages (from transformers) (0.0.43)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.6/dist-packages (from transformers) (4.41.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from transformers) (20.8)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.6/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: tokenizers==0.9.4 in /usr/local/lib/python3.6/dist-packages (from transformers) (0.9.4)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from transformers) (0.8)
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from transformers) (1.19.4)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (1.0.0)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->transformers) (2.4.7)
# --2020-12-21 20:45:06--  https://raw.githubusercontent.com/e9t/nsmc/master/ratings_test.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4893335 (4.7M) [text/plain]
# Saving to: ‘ratings_test.txt.1’
#
# ratings_test.txt.1  100%[===================>]   4.67M  --.-KB/s    in 0.1s
#
# 2020-12-21 20:45:06 (32.4 MB/s) - ‘ratings_test.txt.1’ saved [4893335/4893335]
#
# --2020-12-21 20:45:06--  https://raw.githubusercontent.com/e9t/nsmc/master/ratings_train.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14628807 (14M) [text/plain]
# Saving to: ‘ratings_train.txt.1’
#
# ratings_train.txt.1 100%[===================>]  13.95M  64.8MB/s    in 0.2s
#
# 2020-12-21 20:45:06 (64.8 MB/s) - ‘ratings_train.txt.1’ saved [14628807/14628807]

# %%
# 모델에 필요한 도구 불러오기

import pandas as pd
import torch
from torch.nn import functional as F
from torch.utils.data import DataLoader, Dataset
from transformers import AutoTokenizer, ElectraForSequenceClassification, AdamW
from tqdm.notebook import tqdm

# %%
# GPU 활성화

device = torch.device("cuda")

# %%
device
# Out:
# device(type='cuda')

# %%
# 이미 학습된 모델 로딩하여 사용할 경우  

#model.load_state_dict(torch.load("nsmc kobert.pt"))

# %% [markdown]
# # Create Model

# %%
# Koelectra 모델 사용 ( 버젼은 Base v1,v2,v3 / small v1, v2, v3 선택 가능)
# 가장 높은 성능을 보여주는 Base v3 버젼으로 Fine Tuing 진행

model = ElectraForSequenceClassification.from_pretrained("monologg/koelectra-base-v3-discriminator").to(device)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=467.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=451776329.0, style=ProgressStyle(descri…
# Some weights of the model checkpoint at monologg/koelectra-base-v3-discriminator were not used when initializing ElectraForSequenceClassification: ['discriminator_predictions.dense.weight', 'discriminator_predictions.dense.bias', 'discriminator_predictions.dense_prediction.weight', 'discriminator_predictions.dense_prediction.bias']
# - This IS expected if you are initializing ElectraForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ElectraForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ElectraForSequenceClassification were not initialized from the model checkpoint at monologg/koelectra-base-v3-discriminator and are newly initialized: ['classifier.dense.weight', 'classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %% [markdown]
#  # Train & Test Model
#  ## Train Model

# %%
# 데이터 전처리 
# max_lenth 설정 값 : 50

class NSMCDataset(Dataset):
  
  def __init__(self, csv_file):
    # 일부 값중에 NaN이 있음...
    self.dataset = pd.read_csv(csv_file, sep="\t").dropna(axis=0) 
    # 중복제거
    self.dataset.drop_duplicates(subset=['document'], inplace=True)
    self.tokenizer = AutoTokenizer.from_pretrained("monologg/koelectra-base-v3-discriminator")

    print(self.dataset.describe())
  
  def __len__(self):
    return len(self.dataset)
  def __getitem__(self, idx):
    row = self.dataset.iloc[idx, 1:3].values
    text = row[0]
    y = row[1]

    inputs = self.tokenizer(
        text, 
        return_tensors='pt',
        truncation=True,
        max_length=50,
        pad_to_max_length=True,
        add_special_tokens=True
        )
    
    input_ids = inputs['input_ids'][0]
    attention_mask = inputs['attention_mask'][0]

    return input_ids, attention_mask, y

# %%
# 데이터 로드

train_dataset = NSMCDataset("ratings_train.txt")
test_dataset = NSMCDataset("ratings_test.txt")
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=263326.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=61.0, style=ProgressStyle(description_w…
#                  id          label
# count  1.461820e+05  146182.000000
# mean   6.779186e+06       0.498283
# std    2.919223e+06       0.499999
# min    3.300000e+01       0.000000
# 25%    4.814832e+06       0.000000
# 50%    7.581160e+06       0.000000
# 75%    9.274760e+06       1.000000
# max    1.027815e+07       1.000000
#                  id         label
# count  4.915700e+04  49157.000000
# mean   6.752945e+06      0.502695
# std    2.937158e+06      0.499998
# min    6.010000e+02      0.000000
# 25%    4.777143e+06      0.000000
# 50%    7.565415e+06      1.000000
# 75%    9.260204e+06      1.000000
# max    1.027809e+07      1.000000

# %%
# 에포크, 배치 사이즈 지정, 데이터 로딩

epochs = 10
batch_size = 32

# %%
optimizer = AdamW(model.parameters(), lr=1e-5)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=True)

# %%
 torch.cuda.empty_cache()

# %%
# Koelectra Pretrained 모델을 활용한 FineTuing 진행


losses = []
accuracies = []

for i in range(epochs):
    total_loss = 0.0
    correct = 0
    total = 0
    batches = 0
    
    model.train()
    
    for input_ids_batch, attention_masks_batch, y_batch in tqdm(train_loader):
        optimizer.zero_grad()
        y_batch = y_batch.to(device)
        y_pred = model(input_ids_batch.to(device), attention_mask=attention_masks_batch.to(device))[0]
        loss = F.cross_entropy(y_pred, y_batch)
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()
        
        _, predicted = torch.max(y_pred, 1)
        correct += (predicted == y_batch).sum()
        total += len(y_batch)
        
        batches += 1
        if batches % 100 == 0:
            print("Batch Loss:", total_loss, "Accuracy:", correct.float() / total)
            
    losses.append(total_loss)
    accuracies.append(correct.float() / total)
    print("Train Loss:", total_loss, "Accuracy:", correct.float() / total)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=4569.0), HTML(value='')))
# /usr/local/lib/python3.6/dist-packages/transformers/tokenization_utils_base.py:2179: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# Batch Loss: 61.982283532619476 Accuracy: tensor(0.6675, device='cuda:0')
# Batch Loss: 104.4811854660511 Accuracy: tensor(0.7459, device='cuda:0')
# Batch Loss: 142.8386540710926 Accuracy: tensor(0.7769, device='cuda:0')
# Batch Loss: 177.36984972655773 Accuracy: tensor(0.7972, device='cuda:0')
# Batch Loss: 211.83253636956215 Accuracy: tensor(0.8095, device='cuda:0')
# Batch Loss: 243.04109231382608 Accuracy: tensor(0.8198, device='cuda:0')
# Batch Loss: 274.92407973110676 Accuracy: tensor(0.8272, device='cuda:0')
# Batch Loss: 307.1132615059614 Accuracy: tensor(0.8317, device='cuda:0')
# Batch Loss: 337.3032695353031 Accuracy: tensor(0.8360, device='cuda:0')
# Batch Loss: 366.0610908046365 Accuracy: tensor(0.8408, device='cuda:0')
# Batch Loss: 394.9615585952997 Accuracy: tensor(0.8445, device='cuda:0')
# Batch Loss: 424.5290277376771 Accuracy: tensor(0.8475, device='cuda:0')
# Batch Loss: 452.0566579774022 Accuracy: tensor(0.8504, device='cuda:0')
# Batch Loss: 480.11598071455956 Accuracy: tensor(0.8528, device='cuda:0')
# Batch Loss: 507.72270952165127 Accuracy: tensor(0.8544, device='cuda:0')
# Batch Loss: 536.6656615957618 Accuracy: tensor(0.8556, device='cuda:0')
# Batch Loss: 563.6569977402687 Accuracy: tensor(0.8571, device='cuda:0')
# Batch Loss: 591.501616448164 Accuracy: tensor(0.8587, device='cuda:0')
# Batch Loss: 620.2731109559536 Accuracy: tensor(0.8599, device='cuda:0')
# Batch Loss: 648.0908817127347 Accuracy: tensor(0.8612, device='cuda:0')
# Batch Loss: 675.6633573919535 Accuracy: tensor(0.8623, device='cuda:0')
# Batch Loss: 700.5498971566558 Accuracy: tensor(0.8641, device='cuda:0')
# Batch Loss: 727.7040098756552 Accuracy: tensor(0.8653, device='cuda:0')
# Batch Loss: 752.3864891380072 Accuracy: tensor(0.8667, device='cuda:0')
# Batch Loss: 777.7036696448922 Accuracy: tensor(0.8678, device='cuda:0')
# Batch Loss: 805.1793280690908 Accuracy: tensor(0.8685, device='cuda:0')
# Batch Loss: 832.8524802625179 Accuracy: tensor(0.8692, device='cuda:0')
# Batch Loss: 860.7165294140577 Accuracy: tensor(0.8698, device='cuda:0')
# Batch Loss: 886.1765277832747 Accuracy: tensor(0.8707, device='cuda:0')
# Batch Loss: 912.1370776556432 Accuracy: tensor(0.8715, device='cuda:0')
# Batch Loss: 937.0277113653719 Accuracy: tensor(0.8724, device='cuda:0')
# Batch Loss: 963.226630602032 Accuracy: tensor(0.8731, device='cuda:0')
# Batch Loss: 990.876927446574 Accuracy: tensor(0.8735, device='cuda:0')
# Batch Loss: 1016.6898581422865 Accuracy: tensor(0.8740, device='cuda:0')
# Batch Loss: 1041.7168634869158 Accuracy: tensor(0.8747, device='cuda:0')
# Batch Loss: 1068.8754475302994 Accuracy: tensor(0.8750, device='cuda:0')
# Batch Loss: 1094.2188615389168 Accuracy: tensor(0.8756, device='cuda:0')
# Batch Loss: 1118.3963531441987 Accuracy: tensor(0.8762, device='cuda:0')
# Batch Loss: 1143.5581499747932 Accuracy: tensor(0.8768, device='cuda:0')
# Batch Loss: 1169.8258964531124 Accuracy: tensor(0.8770, device='cuda:0')
# Batch Loss: 1193.4328474216163 Accuracy: tensor(0.8776, device='cuda:0')
# Batch Loss: 1221.2195881269872 Accuracy: tensor(0.8777, device='cuda:0')
# Batch Loss: 1244.9414270706475 Accuracy: tensor(0.8782, device='cuda:0')
# Batch Loss: 1269.9367217384279 Accuracy: tensor(0.8788, device='cuda:0')
# Batch Loss: 1295.8904852308333 Accuracy: tensor(0.8791, device='cuda:0')
#
# Train Loss: 1313.905930813402 Accuracy: tensor(0.8794, device='cuda:0')
# HBox(children=(FloatProgress(value=0.0, max=4569.0), HTML(value='')))
# Batch Loss: 22.652656260877848 Accuracy: tensor(0.9103, device='cuda:0')
# Batch Loss: 43.177033154293895 Accuracy: tensor(0.9147, device='cuda:0')
# Batch Loss: 64.76420160196722 Accuracy: tensor(0.9154, device='cuda:0')
# Batch Loss: 86.27851049415767 Accuracy: tensor(0.9145, device='cuda:0')
# Batch Loss: 108.04564514197409 Accuracy: tensor(0.9149, device='cuda:0')
# Batch Loss: 128.6030208300799 Accuracy: tensor(0.9148, device='cuda:0')
# Batch Loss: 149.59452587924898 Accuracy: tensor(0.9146, device='cuda:0')
# Batch Loss: 171.83655349723995 Accuracy: tensor(0.9138, device='cuda:0')
# Batch Loss: 192.37909190915525 Accuracy: tensor(0.9140, device='cuda:0')
# Batch Loss: 213.32929011248052 Accuracy: tensor(0.9140, device='cuda:0')
# Batch Loss: 236.59419791959226 Accuracy: tensor(0.9134, device='cuda:0')
# Batch Loss: 257.8486799579114 Accuracy: tensor(0.9139, device='cuda:0')
# Batch Loss: 278.78227517567575 Accuracy: tensor(0.9145, device='cuda:0')
# Batch Loss: 299.8629460949451 Accuracy: tensor(0.9144, device='cuda:0')
# Batch Loss: 319.68099133484066 Accuracy: tensor(0.9148, device='cuda:0')
# Batch Loss: 340.54577871598303 Accuracy: tensor(0.9149, device='cuda:0')
# Batch Loss: 360.5982122886926 Accuracy: tensor(0.9150, device='cuda:0')
# Batch Loss: 381.2138698231429 Accuracy: tensor(0.9150, device='cuda:0')
# Batch Loss: 403.5179544892162 Accuracy: tensor(0.9146, device='cuda:0')
# Batch Loss: 428.1925966683775 Accuracy: tensor(0.9138, device='cuda:0')
# Batch Loss: 453.12669124640524 Accuracy: tensor(0.9129, device='cuda:0')
# Batch Loss: 478.03789816237986 Accuracy: tensor(0.9122, device='cuda:0')
# Batch Loss: 503.65388228185475 Accuracy: tensor(0.9115, device='cuda:0')
# Batch Loss: 525.5204152520746 Accuracy: tensor(0.9116, device='cuda:0')
# Batch Loss: 547.559399580583 Accuracy: tensor(0.9118, device='cuda:0')
# Batch Loss: 567.8805022183806 Accuracy: tensor(0.9120, device='cuda:0')
# Batch Loss: 589.5653214696795 Accuracy: tensor(0.9118, device='cuda:0')
# Batch Loss: 610.490549037233 Accuracy: tensor(0.9120, device='cuda:0')
# Batch Loss: 633.6403288114816 Accuracy: tensor(0.9119, device='cuda:0')
# Batch Loss: 657.4316279161721 Accuracy: tensor(0.9114, device='cuda:0')
# Batch Loss: 681.4692894313484 Accuracy: tensor(0.9112, device='cuda:0')
# Batch Loss: 706.34700592421 Accuracy: tensor(0.9108, device='cuda:0')
# Batch Loss: 728.8387237098068 Accuracy: tensor(0.9106, device='cuda:0')
# Batch Loss: 752.3904081080109 Accuracy: tensor(0.9104, device='cuda:0')
# Batch Loss: 774.7792907748371 Accuracy: tensor(0.9104, device='cuda:0')
# Batch Loss: 797.9351176414639 Accuracy: tensor(0.9103, device='cuda:0')
# Batch Loss: 821.0740716475993 Accuracy: tensor(0.9101, device='cuda:0')
# Batch Loss: 843.8755708206445 Accuracy: tensor(0.9102, device='cuda:0')
# Batch Loss: 865.7249437216669 Accuracy: tensor(0.9102, device='cuda:0')
# Batch Loss: 888.753383634612 Accuracy: tensor(0.9101, device='cuda:0')
# Batch Loss: 911.2368356566876 Accuracy: tensor(0.9101, device='cuda:0')
# Batch Loss: 933.1615319680423 Accuracy: tensor(0.9101, device='cuda:0')
# Batch Loss: 954.7879365924746 Accuracy: tensor(0.9101, device='cuda:0')
# Batch Loss: 978.5025482866913 Accuracy: tensor(0.9100, device='cuda:0')
# Batch Loss: 1000.3936439547688 Accuracy: tensor(0.9101, device='cuda:0')
#
# Train Loss: 1016.8588439393789 Accuracy: tensor(0.9099, device='cuda:0')
# HBox(children=(FloatProgress(value=0.0, max=4569.0), HTML(value='')))
# Batch Loss: 17.70765708759427 Accuracy: tensor(0.9300, device='cuda:0')
# Batch Loss: 36.6241379249841 Accuracy: tensor(0.9252, device='cuda:0')
# Batch Loss: 56.51427700556815 Accuracy: tensor(0.9234, device='cuda:0')
# Batch Loss: 75.87677404843271 Accuracy: tensor(0.9244, device='cuda:0')
# Batch Loss: 94.25414116121829 Accuracy: tensor(0.9249, device='cuda:0')
# Batch Loss: 112.4835603479296 Accuracy: tensor(0.9263, device='cuda:0')
# Batch Loss: 130.19023353606462 Accuracy: tensor(0.9271, device='cuda:0')
# Batch Loss: 146.32774511352181 Accuracy: tensor(0.9282, device='cuda:0')
# Batch Loss: 163.46242844685912 Accuracy: tensor(0.9286, device='cuda:0')
# Batch Loss: 181.56541807577014 Accuracy: tensor(0.9288, device='cuda:0')
# Batch Loss: 199.8841311223805 Accuracy: tensor(0.9288, device='cuda:0')
# Batch Loss: 216.69472427107394 Accuracy: tensor(0.9293, device='cuda:0')
# Batch Loss: 234.98473595641553 Accuracy: tensor(0.9293, device='cuda:0')
# Batch Loss: 252.51164081133902 Accuracy: tensor(0.9294, device='cuda:0')
# Batch Loss: 269.1425891611725 Accuracy: tensor(0.9298, device='cuda:0')
# Batch Loss: 285.69925542734563 Accuracy: tensor(0.9301, device='cuda:0')
# Batch Loss: 304.66355021111667 Accuracy: tensor(0.9298, device='cuda:0')
# Batch Loss: 322.2219519186765 Accuracy: tensor(0.9299, device='cuda:0')
# Batch Loss: 339.57702724821866 Accuracy: tensor(0.9300, device='cuda:0')
# Batch Loss: 356.5965033303946 Accuracy: tensor(0.9302, device='cuda:0')
# Batch Loss: 373.7995514459908 Accuracy: tensor(0.9304, device='cuda:0')
# Batch Loss: 391.99487967044115 Accuracy: tensor(0.9302, device='cuda:0')
# Batch Loss: 408.8315042871982 Accuracy: tensor(0.9306, device='cuda:0')
# Batch Loss: 426.7735624667257 Accuracy: tensor(0.9307, device='cuda:0')
# Batch Loss: 444.4683759640902 Accuracy: tensor(0.9307, device='cuda:0')
# Batch Loss: 463.7486425116658 Accuracy: tensor(0.9304, device='cuda:0')
# Batch Loss: 482.34369776397943 Accuracy: tensor(0.9304, device='cuda:0')
# Batch Loss: 497.9530506171286 Accuracy: tensor(0.9307, device='cuda:0')
# Batch Loss: 515.8750027529895 Accuracy: tensor(0.9305, device='cuda:0')
# Batch Loss: 534.2053758352995 Accuracy: tensor(0.9304, device='cuda:0')
# Batch Loss: 551.8856271617115 Accuracy: tensor(0.9303, device='cuda:0')
# Batch Loss: 569.4556813836098 Accuracy: tensor(0.9304, device='cuda:0')
# Batch Loss: 586.1773175634444 Accuracy: tensor(0.9305, device='cuda:0')
# Batch Loss: 603.9566581174731 Accuracy: tensor(0.9304, device='cuda:0')
# Batch Loss: 622.59076237306 Accuracy: tensor(0.9303, device='cuda:0')
# Batch Loss: 638.6316305343062 Accuracy: tensor(0.9305, device='cuda:0')
# Batch Loss: 656.9652031157166 Accuracy: tensor(0.9304, device='cuda:0')
# Batch Loss: 675.8858950119466 Accuracy: tensor(0.9304, device='cuda:0')
# Batch Loss: 694.547698745504 Accuracy: tensor(0.9303, device='cuda:0')
# Batch Loss: 712.123403435573 Accuracy: tensor(0.9303, device='cuda:0')
# Batch Loss: 729.0650952290744 Accuracy: tensor(0.9303, device='cuda:0')
# Batch Loss: 746.894102839753 Accuracy: tensor(0.9303, device='cuda:0')
# Batch Loss: 765.2447260767221 Accuracy: tensor(0.9302, device='cuda:0')
# Batch Loss: 783.2473860271275 Accuracy: tensor(0.9303, device='cuda:0')
# Batch Loss: 800.7332510277629 Accuracy: tensor(0.9304, device='cuda:0')
#
# Train Loss: 813.3920396454632 Accuracy: tensor(0.9304, device='cuda:0')
# HBox(children=(FloatProgress(value=0.0, max=4569.0), HTML(value='')))
# Batch Loss: 13.888021349906921 Accuracy: tensor(0.9506, device='cuda:0')
# Batch Loss: 28.90570930019021 Accuracy: tensor(0.9458, device='cuda:0')
# Batch Loss: 43.55097882822156 Accuracy: tensor(0.9448, device='cuda:0')
# Batch Loss: 57.199090868234634 Accuracy: tensor(0.9455, device='cuda:0')
# Batch Loss: 71.4700954305008 Accuracy: tensor(0.9457, device='cuda:0')
# Batch Loss: 87.61782959382981 Accuracy: tensor(0.9446, device='cuda:0')
# Batch Loss: 102.66467922460288 Accuracy: tensor(0.9440, device='cuda:0')
# Batch Loss: 116.61588096804917 Accuracy: tensor(0.9446, device='cuda:0')
# Batch Loss: 131.90803046524525 Accuracy: tensor(0.9443, device='cuda:0')
# Batch Loss: 145.11714367195964 Accuracy: tensor(0.9448, device='cuda:0')
# Batch Loss: 159.21199762448668 Accuracy: tensor(0.9449, device='cuda:0')
# Batch Loss: 173.97081557288766 Accuracy: tensor(0.9449, device='cuda:0')
# Batch Loss: 186.84603766072541 Accuracy: tensor(0.9453, device='cuda:0')
# Batch Loss: 199.7717631245032 Accuracy: tensor(0.9458, device='cuda:0')
# Batch Loss: 214.68971190601587 Accuracy: tensor(0.9455, device='cuda:0')
# Batch Loss: 229.47371100075543 Accuracy: tensor(0.9454, device='cuda:0')
# Batch Loss: 244.2918698899448 Accuracy: tensor(0.9454, device='cuda:0')
# Batch Loss: 258.5468574706465 Accuracy: tensor(0.9454, device='cuda:0')
# Batch Loss: 274.54406663402915 Accuracy: tensor(0.9452, device='cuda:0')
# Batch Loss: 287.57774592749774 Accuracy: tensor(0.9454, device='cuda:0')
# Batch Loss: 302.44199261814356 Accuracy: tensor(0.9453, device='cuda:0')
# Batch Loss: 318.5229301340878 Accuracy: tensor(0.9448, device='cuda:0')
# Batch Loss: 333.2945713698864 Accuracy: tensor(0.9448, device='cuda:0')
# Batch Loss: 347.7702836934477 Accuracy: tensor(0.9448, device='cuda:0')
# Batch Loss: 362.4711141111329 Accuracy: tensor(0.9447, device='cuda:0')
# Batch Loss: 375.46257112175226 Accuracy: tensor(0.9449, device='cuda:0')
# Batch Loss: 391.09878706373274 Accuracy: tensor(0.9447, device='cuda:0')
# Batch Loss: 406.9933943953365 Accuracy: tensor(0.9445, device='cuda:0')
# Batch Loss: 421.9146396499127 Accuracy: tensor(0.9445, device='cuda:0')
# Batch Loss: 436.57850592024624 Accuracy: tensor(0.9445, device='cuda:0')
# Batch Loss: 449.9951525516808 Accuracy: tensor(0.9446, device='cuda:0')
# Batch Loss: 462.72436200268567 Accuracy: tensor(0.9448, device='cuda:0')
# Batch Loss: 477.29282254725695 Accuracy: tensor(0.9448, device='cuda:0')
# Batch Loss: 492.57297180593014 Accuracy: tensor(0.9447, device='cuda:0')
# Batch Loss: 508.67544937320054 Accuracy: tensor(0.9444, device='cuda:0')
# Batch Loss: 524.049181194976 Accuracy: tensor(0.9444, device='cuda:0')
# Batch Loss: 540.1682483702898 Accuracy: tensor(0.9443, device='cuda:0')
# Batch Loss: 554.4608449991792 Accuracy: tensor(0.9442, device='cuda:0')
# Batch Loss: 568.7919876724482 Accuracy: tensor(0.9443, device='cuda:0')
# Batch Loss: 583.41006800998 Accuracy: tensor(0.9443, device='cuda:0')
# Batch Loss: 598.9304367387667 Accuracy: tensor(0.9443, device='cuda:0')
# Batch Loss: 613.7550244340673 Accuracy: tensor(0.9443, device='cuda:0')
# Batch Loss: 628.576147149317 Accuracy: tensor(0.9443, device='cuda:0')
# Batch Loss: 644.3621381698176 Accuracy: tensor(0.9441, device='cuda:0')
# Batch Loss: 659.1435927757993 Accuracy: tensor(0.9442, device='cuda:0')
#
# Train Loss: 667.9796953611076 Accuracy: tensor(0.9443, device='cuda:0')
# HBox(children=(FloatProgress(value=0.0, max=4569.0), HTML(value='')))
# Batch Loss: 10.07603788562119 Accuracy: tensor(0.9625, device='cuda:0')
# Batch Loss: 22.069059124216437 Accuracy: tensor(0.9578, device='cuda:0')
# Batch Loss: 32.943648227490485 Accuracy: tensor(0.9581, device='cuda:0')
# Batch Loss: 43.76415418740362 Accuracy: tensor(0.9592, device='cuda:0')
# Batch Loss: 53.6546830595471 Accuracy: tensor(0.9603, device='cuda:0')
# Batch Loss: 65.66424762876704 Accuracy: tensor(0.9592, device='cuda:0')
# Batch Loss: 76.93986983085051 Accuracy: tensor(0.9592, device='cuda:0')
# Batch Loss: 88.06278535211459 Accuracy: tensor(0.9589, device='cuda:0')
# Batch Loss: 99.42056603170931 Accuracy: tensor(0.9588, device='cuda:0')
# Batch Loss: 110.55963512510061 Accuracy: tensor(0.9588, device='cuda:0')
# Batch Loss: 123.66828735452145 Accuracy: tensor(0.9582, device='cuda:0')
# Batch Loss: 133.6351667912677 Accuracy: tensor(0.9589, device='cuda:0')
# Batch Loss: 144.94654341507703 Accuracy: tensor(0.9589, device='cuda:0')
# Batch Loss: 156.0432532466948 Accuracy: tensor(0.9592, device='cuda:0')
# Batch Loss: 168.47567899897695 Accuracy: tensor(0.9591, device='cuda:0')
# Batch Loss: 180.0159410201013 Accuracy: tensor(0.9589, device='cuda:0')
# Batch Loss: 191.04449626989663 Accuracy: tensor(0.9590, device='cuda:0')
# Batch Loss: 202.62253283243626 Accuracy: tensor(0.9590, device='cuda:0')
# Batch Loss: 212.96052474342287 Accuracy: tensor(0.9591, device='cuda:0')
# Batch Loss: 224.23023667745292 Accuracy: tensor(0.9588, device='cuda:0')
# Batch Loss: 235.7348711360246 Accuracy: tensor(0.9588, device='cuda:0')
# Batch Loss: 247.13078188337386 Accuracy: tensor(0.9587, device='cuda:0')
# Batch Loss: 258.3056191522628 Accuracy: tensor(0.9586, device='cuda:0')
# Batch Loss: 268.5741592843551 Accuracy: tensor(0.9587, device='cuda:0')
# Batch Loss: 280.43072065268643 Accuracy: tensor(0.9587, device='cuda:0')
# Batch Loss: 291.27714331564493 Accuracy: tensor(0.9588, device='cuda:0')
# Batch Loss: 302.11761906486936 Accuracy: tensor(0.9589, device='cuda:0')
# Batch Loss: 313.4487410292495 Accuracy: tensor(0.9589, device='cuda:0')
# Batch Loss: 325.2654106908012 Accuracy: tensor(0.9589, device='cuda:0')
# Batch Loss: 335.61487800371833 Accuracy: tensor(0.9591, device='cuda:0')
# Batch Loss: 347.8764726987574 Accuracy: tensor(0.9589, device='cuda:0')
# Batch Loss: 360.02912304666825 Accuracy: tensor(0.9588, device='cuda:0')
# Batch Loss: 370.10877562710084 Accuracy: tensor(0.9590, device='cuda:0')
# Batch Loss: 382.6473681994248 Accuracy: tensor(0.9589, device='cuda:0')
# Batch Loss: 394.7395646844525 Accuracy: tensor(0.9587, device='cuda:0')
# Batch Loss: 405.73480071430095 Accuracy: tensor(0.9587, device='cuda:0')
# Batch Loss: 416.4664139125962 Accuracy: tensor(0.9588, device='cuda:0')
# Batch Loss: 429.5098485557828 Accuracy: tensor(0.9587, device='cuda:0')
# Batch Loss: 441.0899883231614 Accuracy: tensor(0.9585, device='cuda:0')
# Batch Loss: 453.44819724024273 Accuracy: tensor(0.9584, device='cuda:0')
# Batch Loss: 464.8005898951087 Accuracy: tensor(0.9584, device='cuda:0')
# Batch Loss: 477.92816048604436 Accuracy: tensor(0.9583, device='cuda:0')
# Batch Loss: 489.4214753296692 Accuracy: tensor(0.9583, device='cuda:0')
# Batch Loss: 503.1174505103845 Accuracy: tensor(0.9582, device='cuda:0')
# Batch Loss: 514.5312527336646 Accuracy: tensor(0.9583, device='cuda:0')
#
# Train Loss: 522.9718890630174 Accuracy: tensor(0.9582, device='cuda:0')
# HBox(children=(FloatProgress(value=0.0, max=4569.0), HTML(value='')))
# Batch Loss: 8.328623315319419 Accuracy: tensor(0.9716, device='cuda:0')
# Batch Loss: 16.926647580228746 Accuracy: tensor(0.9709, device='cuda:0')
# Batch Loss: 24.722456654999405 Accuracy: tensor(0.9720, device='cuda:0')
# Batch Loss: 35.371826756279916 Accuracy: tensor(0.9705, device='cuda:0')
# Batch Loss: 43.51849257852882 Accuracy: tensor(0.9705, device='cuda:0')
# Batch Loss: 52.033147271722555 Accuracy: tensor(0.9702, device='cuda:0')
# Batch Loss: 60.448123997077346 Accuracy: tensor(0.9694, device='cuda:0')
# Batch Loss: 69.10093080019578 Accuracy: tensor(0.9700, device='cuda:0')
# Batch Loss: 76.25240863952786 Accuracy: tensor(0.9706, device='cuda:0')
# Batch Loss: 85.0838473495096 Accuracy: tensor(0.9703, device='cuda:0')
# Batch Loss: 94.78902506548911 Accuracy: tensor(0.9697, device='cuda:0')
# Batch Loss: 102.18787797400728 Accuracy: tensor(0.9701, device='cuda:0')
# Batch Loss: 110.89624864142388 Accuracy: tensor(0.9697, device='cuda:0')
# Batch Loss: 119.80029825260863 Accuracy: tensor(0.9696, device='cuda:0')
# Batch Loss: 128.4826967017725 Accuracy: tensor(0.9694, device='cuda:0')
# Batch Loss: 138.25797434989363 Accuracy: tensor(0.9692, device='cuda:0')
# Batch Loss: 146.9541187407449 Accuracy: tensor(0.9692, device='cuda:0')
# Batch Loss: 156.6746354009956 Accuracy: tensor(0.9690, device='cuda:0')
# Batch Loss: 166.83521682582796 Accuracy: tensor(0.9689, device='cuda:0')
# Batch Loss: 176.45357637666166 Accuracy: tensor(0.9688, device='cuda:0')
# Batch Loss: 184.2005405658856 Accuracy: tensor(0.9689, device='cuda:0')
# Batch Loss: 193.059501090087 Accuracy: tensor(0.9690, device='cuda:0')
# Batch Loss: 201.79251809371635 Accuracy: tensor(0.9691, device='cuda:0')
# Batch Loss: 210.36891010939144 Accuracy: tensor(0.9690, device='cuda:0')
# Batch Loss: 219.36655846307985 Accuracy: tensor(0.9689, device='cuda:0')
# Batch Loss: 228.432815577602 Accuracy: tensor(0.9689, device='cuda:0')
# Batch Loss: 237.8187650272157 Accuracy: tensor(0.9687, device='cuda:0')
# Batch Loss: 248.21157093695365 Accuracy: tensor(0.9685, device='cuda:0')
# Batch Loss: 255.65263598249294 Accuracy: tensor(0.9687, device='cuda:0')
# Batch Loss: 264.2787699622568 Accuracy: tensor(0.9686, device='cuda:0')
# Batch Loss: 274.41083050030284 Accuracy: tensor(0.9685, device='cuda:0')
# Batch Loss: 282.73244629311375 Accuracy: tensor(0.9685, device='cuda:0')
# Batch Loss: 293.1720616633538 Accuracy: tensor(0.9682, device='cuda:0')
# Batch Loss: 302.28636766574346 Accuracy: tensor(0.9682, device='cuda:0')
# Batch Loss: 311.4050393968355 Accuracy: tensor(0.9682, device='cuda:0')
# Batch Loss: 320.18448602431454 Accuracy: tensor(0.9683, device='cuda:0')
# Batch Loss: 328.27103890827857 Accuracy: tensor(0.9684, device='cuda:0')
# Batch Loss: 338.61946672736667 Accuracy: tensor(0.9682, device='cuda:0')
# Batch Loss: 346.7841565448325 Accuracy: tensor(0.9683, device='cuda:0')
# Batch Loss: 354.8409439937677 Accuracy: tensor(0.9685, device='cuda:0')
# Batch Loss: 364.31014194409363 Accuracy: tensor(0.9684, device='cuda:0')
# Batch Loss: 373.1247773494106 Accuracy: tensor(0.9685, device='cuda:0')
# Batch Loss: 381.9792029268574 Accuracy: tensor(0.9685, device='cuda:0')
# Batch Loss: 391.884965487523 Accuracy: tensor(0.9684, device='cuda:0')
# Batch Loss: 401.2207922905218 Accuracy: tensor(0.9683, device='cuda:0')
#
# Train Loss: 406.79359528119676 Accuracy: tensor(0.9683, device='cuda:0')
# HBox(children=(FloatProgress(value=0.0, max=4569.0), HTML(value='')))
# Batch Loss: 4.580923170316964 Accuracy: tensor(0.9853, device='cuda:0')
# Batch Loss: 10.371839098632336 Accuracy: tensor(0.9825, device='cuda:0')
# Batch Loss: 17.809583419002593 Accuracy: tensor(0.9799, device='cuda:0')
# Batch Loss: 24.936896388186142 Accuracy: tensor(0.9793, device='cuda:0')
# Batch Loss: 31.085446709999815 Accuracy: tensor(0.9790, device='cuda:0')
# Batch Loss: 37.55621574143879 Accuracy: tensor(0.9784, device='cuda:0')
# Batch Loss: 44.3521341921296 Accuracy: tensor(0.9781, device='cuda:0')
# Batch Loss: 51.51063423510641 Accuracy: tensor(0.9778, device='cuda:0')
# Batch Loss: 58.54462549625896 Accuracy: tensor(0.9775, device='cuda:0')
# Batch Loss: 64.0218079064507 Accuracy: tensor(0.9777, device='cuda:0')
# Batch Loss: 70.35414918255992 Accuracy: tensor(0.9779, device='cuda:0')
# Batch Loss: 76.79471617541276 Accuracy: tensor(0.9777, device='cuda:0')
# Batch Loss: 83.55919947312213 Accuracy: tensor(0.9776, device='cuda:0')
# Batch Loss: 90.86979257594794 Accuracy: tensor(0.9775, device='cuda:0')
# Batch Loss: 98.3720090445131 Accuracy: tensor(0.9773, device='cuda:0')
# Batch Loss: 106.0216890766751 Accuracy: tensor(0.9771, device='cuda:0')
# Batch Loss: 112.70636200415902 Accuracy: tensor(0.9772, device='cuda:0')
# Batch Loss: 120.67790290317498 Accuracy: tensor(0.9769, device='cuda:0')
# Batch Loss: 129.4890539252665 Accuracy: tensor(0.9764, device='cuda:0')
# Batch Loss: 136.281543150777 Accuracy: tensor(0.9763, device='cuda:0')
# Batch Loss: 142.2641177161131 Accuracy: tensor(0.9764, device='cuda:0')
# Batch Loss: 149.1704656535294 Accuracy: tensor(0.9764, device='cuda:0')
# Batch Loss: 155.5528361061588 Accuracy: tensor(0.9765, device='cuda:0')
# Batch Loss: 161.83209108840674 Accuracy: tensor(0.9764, device='cuda:0')
# Batch Loss: 168.25677088764496 Accuracy: tensor(0.9764, device='cuda:0')
# Batch Loss: 176.64824823569506 Accuracy: tensor(0.9762, device='cuda:0')
# Batch Loss: 183.48872401705012 Accuracy: tensor(0.9761, device='cuda:0')
# Batch Loss: 191.07408259343356 Accuracy: tensor(0.9760, device='cuda:0')
# Batch Loss: 198.25556269055232 Accuracy: tensor(0.9760, device='cuda:0')
# Batch Loss: 205.63329181913286 Accuracy: tensor(0.9760, device='cuda:0')
# Batch Loss: 212.85417814250104 Accuracy: tensor(0.9759, device='cuda:0')
# Batch Loss: 221.03460401459597 Accuracy: tensor(0.9759, device='cuda:0')
# Batch Loss: 227.7891635731794 Accuracy: tensor(0.9759, device='cuda:0')
# Batch Loss: 235.39505514898337 Accuracy: tensor(0.9758, device='cuda:0')
# Batch Loss: 242.52066740416922 Accuracy: tensor(0.9758, device='cuda:0')
# Batch Loss: 249.0449148779735 Accuracy: tensor(0.9758, device='cuda:0')
# Batch Loss: 256.68252802081406 Accuracy: tensor(0.9757, device='cuda:0')
# Batch Loss: 264.2898849043995 Accuracy: tensor(0.9757, device='cuda:0')
# Batch Loss: 272.02073814719915 Accuracy: tensor(0.9757, device='cuda:0')
# Batch Loss: 279.97477996442467 Accuracy: tensor(0.9756, device='cuda:0')
# Batch Loss: 287.5240172473714 Accuracy: tensor(0.9755, device='cuda:0')
# Batch Loss: 295.1545804506168 Accuracy: tensor(0.9754, device='cuda:0')
# Batch Loss: 302.46140684350394 Accuracy: tensor(0.9754, device='cuda:0')
# Batch Loss: 309.48130158963613 Accuracy: tensor(0.9754, device='cuda:0')
# Batch Loss: 316.1955869330559 Accuracy: tensor(0.9754, device='cuda:0')
#
# Train Loss: 319.97024575574324 Accuracy: tensor(0.9755, device='cuda:0')
# HBox(children=(FloatProgress(value=0.0, max=4569.0), HTML(value='')))
# Batch Loss: 4.447977642528713 Accuracy: tensor(0.9844, device='cuda:0')
# Batch Loss: 9.00682754558511 Accuracy: tensor(0.9842, device='cuda:0')
# Batch Loss: 13.715191145660356 Accuracy: tensor(0.9842, device='cuda:0')
# Batch Loss: 19.144155727233738 Accuracy: tensor(0.9837, device='cuda:0')
# Batch Loss: 24.106410957872868 Accuracy: tensor(0.9837, device='cuda:0')
# Batch Loss: 29.90081956004724 Accuracy: tensor(0.9832, device='cuda:0')
# Batch Loss: 35.04149288800545 Accuracy: tensor(0.9828, device='cuda:0')
# Batch Loss: 41.12811310798861 Accuracy: tensor(0.9825, device='cuda:0')
# Batch Loss: 46.18368917820044 Accuracy: tensor(0.9826, device='cuda:0')
# Batch Loss: 52.238532338058576 Accuracy: tensor(0.9824, device='cuda:0')
# Batch Loss: 57.959606748772785 Accuracy: tensor(0.9823, device='cuda:0')
# Batch Loss: 65.79385544010438 Accuracy: tensor(0.9819, device='cuda:0')
# Batch Loss: 72.02024322119541 Accuracy: tensor(0.9816, device='cuda:0')
# Batch Loss: 77.04648622660898 Accuracy: tensor(0.9817, device='cuda:0')
# Batch Loss: 82.85729167074896 Accuracy: tensor(0.9814, device='cuda:0')
# Batch Loss: 88.06729698576964 Accuracy: tensor(0.9813, device='cuda:0')
# Batch Loss: 94.10682935942896 Accuracy: tensor(0.9813, device='cuda:0')
# Batch Loss: 100.20969162904657 Accuracy: tensor(0.9812, device='cuda:0')
# Batch Loss: 106.14885497419164 Accuracy: tensor(0.9812, device='cuda:0')
# Batch Loss: 113.00776489148848 Accuracy: tensor(0.9807, device='cuda:0')
# Batch Loss: 118.99461715226062 Accuracy: tensor(0.9807, device='cuda:0')
# Batch Loss: 125.8070262381807 Accuracy: tensor(0.9806, device='cuda:0')
# Batch Loss: 131.0269521670416 Accuracy: tensor(0.9807, device='cuda:0')
# Batch Loss: 136.65407730499282 Accuracy: tensor(0.9808, device='cuda:0')
# Batch Loss: 143.02006707084365 Accuracy: tensor(0.9807, device='cuda:0')
# Batch Loss: 147.82772917416878 Accuracy: tensor(0.9808, device='cuda:0')
# Batch Loss: 153.99719294090755 Accuracy: tensor(0.9806, device='cuda:0')
# Batch Loss: 160.27078438736498 Accuracy: tensor(0.9806, device='cuda:0')
# Batch Loss: 166.65651847491972 Accuracy: tensor(0.9804, device='cuda:0')
# Batch Loss: 171.38932802411728 Accuracy: tensor(0.9806, device='cuda:0')
# Batch Loss: 177.13715779571794 Accuracy: tensor(0.9805, device='cuda:0')
# Batch Loss: 182.5014037922956 Accuracy: tensor(0.9806, device='cuda:0')
# Batch Loss: 189.88872018223628 Accuracy: tensor(0.9805, device='cuda:0')
# Batch Loss: 194.86277297488414 Accuracy: tensor(0.9806, device='cuda:0')
# Batch Loss: 201.42307979939505 Accuracy: tensor(0.9805, device='cuda:0')
# Batch Loss: 208.51553127425723 Accuracy: tensor(0.9803, device='cuda:0')
# Batch Loss: 214.7802179378923 Accuracy: tensor(0.9803, device='cuda:0')
# Batch Loss: 221.27518364787102 Accuracy: tensor(0.9802, device='cuda:0')
# Batch Loss: 227.16552366199903 Accuracy: tensor(0.9802, device='cuda:0')
# Batch Loss: 232.17340009636246 Accuracy: tensor(0.9803, device='cuda:0')
# Batch Loss: 237.87279264372773 Accuracy: tensor(0.9803, device='cuda:0')
# Batch Loss: 244.78367495466955 Accuracy: tensor(0.9802, device='cuda:0')
# Batch Loss: 250.2168813580647 Accuracy: tensor(0.9802, device='cuda:0')
# Batch Loss: 257.0647552963346 Accuracy: tensor(0.9802, device='cuda:0')
# Batch Loss: 263.1639608768746 Accuracy: tensor(0.9803, device='cuda:0')
#
# Train Loss: 267.95815305877477 Accuracy: tensor(0.9802, device='cuda:0')
# HBox(children=(FloatProgress(value=0.0, max=4569.0), HTML(value='')))
# Batch Loss: 3.515591413830407 Accuracy: tensor(0.9887, device='cuda:0')
# Batch Loss: 7.971199957537465 Accuracy: tensor(0.9869, device='cuda:0')
# Batch Loss: 12.316192389582284 Accuracy: tensor(0.9870, device='cuda:0')
# Batch Loss: 17.456570142996497 Accuracy: tensor(0.9858, device='cuda:0')
# Batch Loss: 23.06314617942553 Accuracy: tensor(0.9846, device='cuda:0')
# Batch Loss: 28.815022771363147 Accuracy: tensor(0.9836, device='cuda:0')
# Batch Loss: 32.71832462132443 Accuracy: tensor(0.9839, device='cuda:0')
# Batch Loss: 37.371937516960315 Accuracy: tensor(0.9842, device='cuda:0')
# Batch Loss: 41.889728095033206 Accuracy: tensor(0.9843, device='cuda:0')
# Batch Loss: 45.723280367208645 Accuracy: tensor(0.9845, device='cuda:0')
# Batch Loss: 50.85735861817375 Accuracy: tensor(0.9843, device='cuda:0')
# Batch Loss: 56.58150635752827 Accuracy: tensor(0.9842, device='cuda:0')
# Batch Loss: 60.80019112699665 Accuracy: tensor(0.9845, device='cuda:0')
# Batch Loss: 66.46675070596393 Accuracy: tensor(0.9843, device='cuda:0')
# Batch Loss: 72.07946157327387 Accuracy: tensor(0.9842, device='cuda:0')
# Batch Loss: 76.7888506379677 Accuracy: tensor(0.9842, device='cuda:0')
# Batch Loss: 82.61625540640671 Accuracy: tensor(0.9841, device='cuda:0')
# Batch Loss: 87.05293768725824 Accuracy: tensor(0.9841, device='cuda:0')
# Batch Loss: 91.27399505197536 Accuracy: tensor(0.9842, device='cuda:0')
# Batch Loss: 96.6322268875083 Accuracy: tensor(0.9840, device='cuda:0')
# Batch Loss: 102.42228794039693 Accuracy: tensor(0.9840, device='cuda:0')
# Batch Loss: 107.90185752033722 Accuracy: tensor(0.9838, device='cuda:0')
# Batch Loss: 112.24774607282598 Accuracy: tensor(0.9839, device='cuda:0')
# Batch Loss: 116.26069623546209 Accuracy: tensor(0.9840, device='cuda:0')
# Batch Loss: 120.81121695716865 Accuracy: tensor(0.9840, device='cuda:0')
# Batch Loss: 126.1153637287207 Accuracy: tensor(0.9839, device='cuda:0')
# Batch Loss: 131.85494665568694 Accuracy: tensor(0.9839, device='cuda:0')
# Batch Loss: 136.27946595172398 Accuracy: tensor(0.9839, device='cuda:0')
# Batch Loss: 141.956620558165 Accuracy: tensor(0.9838, device='cuda:0')
# Batch Loss: 147.71898002596572 Accuracy: tensor(0.9837, device='cuda:0')
# Batch Loss: 152.0381772753317 Accuracy: tensor(0.9838, device='cuda:0')
# Batch Loss: 156.95900278282352 Accuracy: tensor(0.9838, device='cuda:0')
# Batch Loss: 161.80854198290035 Accuracy: tensor(0.9837, device='cuda:0')
# Batch Loss: 167.36831297609024 Accuracy: tensor(0.9835, device='cuda:0')
# Batch Loss: 172.38625193119515 Accuracy: tensor(0.9836, device='cuda:0')
# Batch Loss: 178.16832025756594 Accuracy: tensor(0.9835, device='cuda:0')
# Batch Loss: 184.1817571715219 Accuracy: tensor(0.9834, device='cuda:0')
# Batch Loss: 189.16722042870242 Accuracy: tensor(0.9834, device='cuda:0')
# Batch Loss: 193.45386722579133 Accuracy: tensor(0.9834, device='cuda:0')
# Batch Loss: 196.90220880357083 Accuracy: tensor(0.9835, device='cuda:0')
# Batch Loss: 202.30756079603452 Accuracy: tensor(0.9835, device='cuda:0')
# Batch Loss: 208.70874281181023 Accuracy: tensor(0.9834, device='cuda:0')
# Batch Loss: 214.5603598691523 Accuracy: tensor(0.9832, device='cuda:0')
# Batch Loss: 219.68793688737787 Accuracy: tensor(0.9832, device='cuda:0')
# Batch Loss: 225.3511965123471 Accuracy: tensor(0.9832, device='cuda:0')
#
# Train Loss: 229.17974565410987 Accuracy: tensor(0.9832, device='cuda:0')
# HBox(children=(FloatProgress(value=0.0, max=4569.0), HTML(value='')))
# Batch Loss: 3.571237144060433 Accuracy: tensor(0.9875, device='cuda:0')
# Batch Loss: 8.282500049099326 Accuracy: tensor(0.9866, device='cuda:0')
# Batch Loss: 11.363942027790472 Accuracy: tensor(0.9874, device='cuda:0')
# Batch Loss: 15.286352470633574 Accuracy: tensor(0.9872, device='cuda:0')
# Batch Loss: 20.377018545405008 Accuracy: tensor(0.9863, device='cuda:0')
# Batch Loss: 24.480745369568467 Accuracy: tensor(0.9864, device='cuda:0')
# Batch Loss: 28.099346480099484 Accuracy: tensor(0.9866, device='cuda:0')
# Batch Loss: 32.53561920445645 Accuracy: tensor(0.9864, device='cuda:0')
# Batch Loss: 36.60980098793516 Accuracy: tensor(0.9864, device='cuda:0')
# Batch Loss: 41.144536888983566 Accuracy: tensor(0.9864, device='cuda:0')
# Batch Loss: 45.72415708139306 Accuracy: tensor(0.9862, device='cuda:0')
# Batch Loss: 49.617062322970014 Accuracy: tensor(0.9863, device='cuda:0')
# Batch Loss: 54.372718277794775 Accuracy: tensor(0.9862, device='cuda:0')
# Batch Loss: 58.40797273739008 Accuracy: tensor(0.9864, device='cuda:0')
# Batch Loss: 61.99776914314134 Accuracy: tensor(0.9865, device='cuda:0')
# Batch Loss: 66.12737268960336 Accuracy: tensor(0.9865, device='cuda:0')
# Batch Loss: 69.47938145854278 Accuracy: tensor(0.9867, device='cuda:0')
# Batch Loss: 74.16171308403136 Accuracy: tensor(0.9865, device='cuda:0')
# Batch Loss: 77.56918194500031 Accuracy: tensor(0.9867, device='cuda:0')
# Batch Loss: 80.95809047640068 Accuracy: tensor(0.9869, device='cuda:0')
# Batch Loss: 84.88873274269281 Accuracy: tensor(0.9869, device='cuda:0')
# Batch Loss: 89.71274933352834 Accuracy: tensor(0.9867, device='cuda:0')
# Batch Loss: 93.70077377912821 Accuracy: tensor(0.9867, device='cuda:0')
# Batch Loss: 97.96720471599838 Accuracy: tensor(0.9867, device='cuda:0')
# Batch Loss: 101.99794532073429 Accuracy: tensor(0.9868, device='cuda:0')
# Batch Loss: 106.37740881164791 Accuracy: tensor(0.9868, device='cuda:0')
# Batch Loss: 109.92433093459113 Accuracy: tensor(0.9868, device='cuda:0')
# Batch Loss: 114.34478826978011 Accuracy: tensor(0.9868, device='cuda:0')
# Batch Loss: 119.22075720335124 Accuracy: tensor(0.9867, device='cuda:0')
# Batch Loss: 124.2839823657996 Accuracy: tensor(0.9866, device='cuda:0')
# Batch Loss: 128.35079107485944 Accuracy: tensor(0.9866, device='cuda:0')
# Batch Loss: 132.53210422914708 Accuracy: tensor(0.9865, device='cuda:0')
# Batch Loss: 136.6531821314129 Accuracy: tensor(0.9864, device='cuda:0')
# Batch Loss: 141.21272323682206 Accuracy: tensor(0.9864, device='cuda:0')
# Batch Loss: 146.91833378601586 Accuracy: tensor(0.9862, device='cuda:0')
# Batch Loss: 152.31583220948232 Accuracy: tensor(0.9861, device='cuda:0')
# Batch Loss: 156.14934723259648 Accuracy: tensor(0.9861, device='cuda:0')
# Batch Loss: 159.97466700914083 Accuracy: tensor(0.9861, device='cuda:0')
# Batch Loss: 164.79010530741652 Accuracy: tensor(0.9861, device='cuda:0')
# Batch Loss: 169.2079100763076 Accuracy: tensor(0.9860, device='cuda:0')
# Batch Loss: 173.04265643697 Accuracy: tensor(0.9861, device='cuda:0')
# Batch Loss: 176.77795133675681 Accuracy: tensor(0.9861, device='cuda:0')
# Batch Loss: 181.2992379720672 Accuracy: tensor(0.9861, device='cuda:0')
# Batch Loss: 186.2149880247307 Accuracy: tensor(0.9860, device='cuda:0')
# Batch Loss: 191.85526610404486 Accuracy: tensor(0.9859, device='cuda:0')
#
# Train Loss: 194.44499128340976 Accuracy: tensor(0.9859, device='cuda:0')

# %%
losses, accuracies
# Out:
# ([1313.905930813402,
#   1016.8588439393789,
#   813.3920396454632,
#   667.9796953611076,
#   522.9718890630174,
#   406.79359528119676,
#   319.97024575574324,
#   267.95815305877477,
#   229.17974565410987,
#   194.44499128340976],
#  [tensor(0.8794, device='cuda:0'),
#   tensor(0.9099, device='cuda:0'),
#   tensor(0.9304, device='cuda:0'),
#   tensor(0.9443, device='cuda:0'),
#   tensor(0.9582, device='cuda:0'),
#   tensor(0.9683, device='cuda:0'),
#   tensor(0.9755, device='cuda:0'),
#   tensor(0.9802, device='cuda:0'),
#   tensor(0.9832, device='cuda:0'),
#   tensor(0.9859, device='cuda:0')])

# %% [markdown]
#  # Learn & Test Model
#  ## Test Model

# %%
model.eval()

test_correct = 0
test_total = 0

for input_ids_batch, attention_masks_batch, y_batch in tqdm(test_loader):
    y_batch = y_batch.to(device)
    y_pred = model(input_ids_batch.to(device), attention_mask=attention_masks_batch.to(device))[0]
    _, predicted = torch.max(y_pred, 1)
    test_correct += (predicted == y_batch).sum()
    test_total += len(y_batch)

print("Accuracy:", test_correct.float() / test_total)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3073.0), HTML(value='')))
# /usr/local/lib/python3.6/dist-packages/transformers/tokenization_utils_base.py:2179: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# Accuracy: tensor(0.9025, device='cuda:0')

# %%
# 모델 저장하기
torch.save(model.state_dict(), "nsmc kobert.pt")

# %% [markdown]
# # Prediction (W ko_data.csv)

# %%
class NSMCDataset_ko(Dataset):
  
  def __init__(self, csv_file):
    # 일부 값중에 NaN이 있음...
    self.dataset = pd.read_csv(csv_file, sep=',', encoding='CP949').dropna(axis=0) 
    # 중복제거
    #self.dataset.drop_duplicates(subset=['document'], inplace=True)
    self.tokenizer = AutoTokenizer.from_pretrained("monologg/koelectra-base-v3-discriminator")

    print(self.dataset.describe())
  
  def __len__(self):
    return len(self.dataset)

  def __getitem__(self, idx):
    row = self.dataset.iloc[idx, 1:3].values
    text = row[0]
    
    

    # ko_data label 없음
    #y = row[1]

    inputs = self.tokenizer(
        text, 
        return_tensors='pt',
        truncation=True,
        max_length=64,
        pad_to_max_length=True,
        add_special_tokens=True
        )
    

    input_ids = inputs['input_ids'][0]
    attention_mask = inputs['attention_mask'][0]

    return input_ids, attention_mask

# %%
from google.colab import files
myfile = files.upload()
# Out:
#      <input type="file" id="files-84746a9b-6972-4056-b084-e051b129ac19" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-84746a9b-6972-4056-b084-e051b129ac19">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ko_data.csv to ko_data (1).csv

# %%
test_dataset = NSMCDataset_ko("ko_data (1).csv")
# Out:
#                  Id
# count  11187.000000
# mean    5593.000000
# std     3229.553065
# min        0.000000
# 25%     2796.500000
# 50%     5593.000000
# 75%     8389.500000
# max    11186.000000

# %%
# 입력데이터 1개씩 predicted 값 생성을 위해 batch_size 1 로 설정

test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)

# %%
model.eval()

test_preds = []

for input_ids_batch, attention_masks_batch in tqdm(test_loader):

  y_pred = model(input_ids_batch.to(device), attention_mask=attention_masks_batch.to(device))[0]
  _, predicted = torch.max(y_pred, 1)


  preds = y_pred.detach()
  test_preds.append(preds.cpu().numpy())
# Out:
# HBox(children=(FloatProgress(value=0.0, max=11187.0), HTML(value='')))
# /usr/local/lib/python3.6/dist-packages/transformers/tokenization_utils_base.py:2179: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,

# %%
import numpy as np

outputs = []
for _ in test_preds:
    # argmax를 사용해서 가장 높은 확률로 예측한 class 반환
    predicted_class_indices=np.argmax(_, axis=1).tolist()
    outputs.append(predicted_class_indices)

result = np.concatenate(outputs)

# %%
len(result)
# Out:
# 11187

# %%
import pandas as pd

ko_data = pd.read_csv('ko_data (1).csv', delimiter=',', encoding='CP949')

# %%
outfile_df = pd.DataFrame()

outfile_df['Id'] = ko_data['Id']
outfile_df['Predicted'] = result

# %%
outfile_df.to_csv("/content/drive/MyDrive/Colab Notebooks/Submission5.csv", index=False)
